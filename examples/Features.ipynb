# %% [markdown]
# ## ColorLine

# %%
import numpy as np

x = np.linspace(0, 2 * np.pi, 300)

lats = 20 * np.cos(x)
lons = 20 * np.sin(x)
colors = np.sin(5 * x)

# %%
import folium
from folium import features


m = folium.Map([0, 0], zoom_start=3)

color_line = features.ColorLine(
    positions=list(zip(lats, lons)),
    colors=colors,
    colormap=["y", "orange", "r"],
    weight=10,
)

color_line.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_221fd45e7c18ccf946f239d0a3734039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_221fd45e7c18ccf946f239d0a3734039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_221fd45e7c18ccf946f239d0a3734039 = L.map(
#                 &quot;map_221fd45e7c18ccf946f239d0a3734039&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc9278aca74730d50ada82bea5a4b6c2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_221fd45e7c18ccf946f239d0a3734039);
#
#
#             var color_line_b10c7ca1d619fbf332bdf673f1424e5b = L.featureGroup(
#                 {}
#             ).addTo(map_221fd45e7c18ccf946f239d0a3734039);
#
#
#             var poly_line_26b70bd813e11d533e870302695f0fad = L.polyline(
#                 [[[20.0, 0.0], [19.99558428151149, 0.4202490225695083]], [[16.155600744606296, 11.789680427427898], [15.904303731559576, 12.12654620303325]], [[15.904303731559576, 12.12654620303325], [15.645983825709425, 12.458057237211548]], [[6.499219504556906, 18.914548523070465], [6.100343541912352, 19.046936989202443]], [[-6.3001292777989555, 18.98179051309492], [-6.697592243419724, 18.84521844237641]], [[-6.697592243419724, 18.84521844237641], [-7.092097740850713, 18.700324853708295]], [[-16.030837108302038, 11.958773415659582], [-16.278580867064825, 11.619285905529262]], [[-19.998896039909674, -0.21013611037872199], [-19.990065090410354, -0.6303155409454007]], [[-19.990065090410354, -0.6303155409454007], [-19.97240709091041, -1.0502166419133045]], [[-16.519136462777475, -11.274667645839306], [-16.27858086706483, -11.61928590552926]], [[-16.27858086706483, -11.61928590552926], [-16.03083710830204, -11.958773415659579]], [[-5.899884352444995, -19.109980759482063], [-5.4970342042495135, -19.229732576333735]], [[5.698773839291365, -19.170914864153154], [6.1003435419123475, -19.046936989202447]], [[6.1003435419123475, -19.046936989202447], [6.499219504556901, -18.914548523070465]], [[16.399763899162917, -11.447608660838851], [16.636685379653873, -11.100481952528508]], [[19.99558428151149, -0.4202490225695144], [20.0, -4.898587196589413e-15]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffad00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffad00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_b10c7ca1d619fbf332bdf673f1424e5b);
#
#
#             var poly_line_0ed995c00f981f914bd7b93d8efdeabe = L.polyline(
#                 [[[19.99558428151149, 0.4202490225695083], [19.98233907590294, 0.8403124750011428]], [[16.39976389916292, 11.44760866083885], [16.155600744606296, 11.789680427427898]], [[6.100343541912352, 19.046936989202443], [5.69877383929137, 19.170914864153154]], [[5.69877383929137, 19.170914864153154], [5.294687718569988, 19.286427402783133]], [[-5.899884352444991, 19.109980759482067], [-6.3001292777989555, 18.98179051309492]], [[-16.278580867064825, 11.619285905529262], [-16.519136462777475, 11.274667645839312]], [[-16.519136462777475, 11.274667645839312], [-16.75239767286083, 10.925070810311805]], [[-19.990065090410354, 0.6303155409454055], [-19.998896039909674, 0.21013611037872693]], [[-19.998896039909674, 0.21013611037872693], [-19.998896039909674, -0.21013611037872199]], [[-16.03083710830204, -11.958773415659579], [-15.77601458315871, -12.292980268102752]], [[-6.697592243419727, -18.845218442376407], [-6.300129277798961, -18.98179051309492]], [[-6.300129277798961, -18.98179051309492], [-5.899884352444995, -19.109980759482063]], [[6.499219504556901, -18.914548523070465], [6.89522559482874, -18.773807924776975]], [[15.904303731559574, -12.126546203033254], [16.155600744606293, -11.789680427427902]], [[16.155600744606293, -11.789680427427902], [16.399763899162917, -11.447608660838851]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff9600ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff9600ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_b10c7ca1d619fbf332bdf673f1424e5b);
#
#
#             var poly_line_d853ab37b3b84a8

# %% [markdown]
# ### Marker, Icon, Popup

# %%
m = folium.Map([0, 0], zoom_start=1)
mk = features.Marker([0, 0])
pp = folium.Popup("hello")
ic = features.Icon(color="red")

mk.add_child(ic)
mk.add_child(pp)
m.add_child(mk)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_022aa68928b2afb2d68574bc58cd42a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_022aa68928b2afb2d68574bc58cd42a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_022aa68928b2afb2d68574bc58cd42a5 = L.map(
#                 &quot;map_022aa68928b2afb2d68574bc58cd42a5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d25e15b1be4492d4ce52b5c887a8ea8e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_022aa68928b2afb2d68574bc58cd42a5);
#
#
#             var marker_c3d8900d249d488ab455ba75b283c0b6 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_022aa68928b2afb2d68574bc58cd42a5);
#
#
#             var icon_0c37c229f6c988b5401b193406fb541c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3d8900d249d488ab455ba75b283c0b6.setIcon(icon_0c37c229f6c988b5401b193406fb541c);
#
#
#         var popup_7f634fd387dd65937162fd21fcf6542a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c59e41290ec69dab49ac2b6ed74ba284 = $(`&lt;div id=&quot;html_c59e41290ec69dab49ac2b6ed74ba284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello&lt;/div&gt;`)[0];
#             popup_7f634fd387dd65937162fd21fcf6542a.setContent(html_c59e41290ec69dab49ac2b6ed74ba284);
#
#
#         marker_c3d8900d249d488ab455ba75b283c0b6.bindPopup(popup_7f634fd387dd65937162fd21fcf6542a)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Vega popup

# %%
import json

import vincent

N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=100, width=200)
data = json.loads(scatter.to_json())

m = folium.Map([0, 0], zoom_start=1)
mk = features.Marker([0, 0])
p = folium.Popup("Hello")
v = features.Vega(data, width="100%", height="100%")

mk.add_child(p)
p.add_child(v)
m.add_child(mk)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49058597d28de25013505cf7b8570af1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_661baeee1e0621d42dd95182a238beba {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49058597d28de25013505cf7b8570af1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_49058597d28de25013505cf7b8570af1 = L.map(
#                 &quot;map_49058597d28de25013505cf7b8570af1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c71d62f1a8682e5472b4f5ce14a8b11 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49058597d28de25013505cf7b8570af1);
#
#
#             var marker_a1706d49affb7f164cd2c852f8eac35a = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_49058597d28de25013505cf7b8570af1);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_1d4c954a9016a187407defb273f06568 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_057535880d680cbf3084ebc699a19f7c = $(`&lt;div id=&quot;html_057535880d680cbf3084ebc699a19f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello&lt;/div&gt;`)[0];
#             popup_1d4c954a9016a187407defb273f06568.setContent(html_057535880d680cbf3084ebc699a19f7c);
#
#             var vega_661baeee1e0621d42dd95182a238beba = $(`             &lt;div id=&quot;vega_661baeee1e0621d42dd95182a238beba&quot;&gt;&lt;/div&gt;             `)[0];
#             popup_1d4c954a9016a187407defb273f06568.setContent(vega_661baeee1e0621d42dd95182a238beba);
#
#
#         marker_a1706d49affb7f164cd2c852f8eac35a.bindPopup(popup_1d4c954a9016a187407defb273f06568)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.49966489835527295, &quot;val&quot;: 0.9634555539518708}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6153204214278474, &quot;val&quot;: 0.3602300415408475}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9406452316969353, &quot;val&quot;: 0.5572882748427844}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.10902641198637719, &quot;val&quot;: 0.8093953291914499}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8942770469505187, &quot;val&quot;: 0.644534419810812}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5205297242509767, &quot;val&quot;: 0.0923862856414428}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6525315779908685, &quot;val&quot;: 0.6640037068398441}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9015486488615087, &quot;val&quot;: 0.7107692027756454}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7446569792815441, &quot;val&quot;: 0.8606116250265987}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5050469468328047, &quot;val&quot;: 0.41259025643038216}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.4381726194987615, &quot;val&quot;: 0.31489520314069475}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9240738694618441, &quot;val&quot;: 0.18362422226846387}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8648852829281205, &quot;val&quot;: 0.4308799108471906}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7932850083773815, &quot;val&quot;: 0.9793238588879295}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.545910583025444, &quot;val&quot;: 0.06082839220502778}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.33098580096397356, &quot;val&quot;: 0.49631173653323923}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8728636377451141, &quot;val&quot;: 0.6214544886619194}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7376430865666098, &quot;val&quot;: 0.5782896923296692}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9202559570352931, &quot;val&quot;: 0.21239035290965302}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.24078218545264207, &quot;val&quot;: 0.5667004489230757}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8208717807903793, &quot;val&quot;: 0.8811183251576672}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9490306540337298, &quo

# %% [markdown]
# ### Vega-Lite popup

# %%
from altair import Chart, load_dataset
import pandas as pd
# load built-in dataset as a pandas DataFrame
cars = load_dataset("cars")

scatter = (
    Chart(cars)
    .mark_circle()
    .encode(
        x="Horsepower",
        y="Miles_per_Gallon",
        color="Origin",
    )
)

vega = folium.features.VegaLite(
    scatter,
    width="100%",
    height="100%",
)

m = folium.Map(location=[-27.5717, -48.6256])

marker = folium.features.Marker([-27.57, -48.62])

popup = folium.Popup()

vega.add_to(popup)
popup.add_to(marker)

marker.add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       2 import pandas as pd
#       3 # load built-in dataset as a pandas DataFrame
# ----> 4 cars = load_dataset("cars")
#       6 scatter = (
#       7     Chart(cars)
#       8     .mark_circle()
#    (...)
#      13     )
#      14 )
#      16 vega = folium.features.VegaLite(
#      17     scatter,
#      18     width="100%",
#      19     height="100%",
#      20 )
#
# File ~\anaconda3\lib\site-packages\altair\utils\deprecation.py:66, in _deprecate.<locals>.new_obj(*args, **kwargs)
#      63 @functools.wraps(obj)
#      64 def new_obj(*args, **kwargs):
#      65     warnings.warn(message, AltairDeprecationWarning)
# ---> 66     return obj(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\altair\datasets.py:12, in load_dataset(name)
#       9 @deprecated("load_dataset is deprecated. " "Use the vega_datasets package instead.")
#      10 def load_dataset(name):
#      11     """Load a dataset by name as a pandas.DataFrame."""
# ---> 12     import vega_datasets
#      14     return vega_datasets.data(name)
#
# ModuleNotFoundError: No module named 'vega_datasets'

# %% [markdown]
# ### Vega div and a Map

# %%
import branca

N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m = folium.Map(
    location=[0, 0],
    tiles="stamenwatercolor",
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m2 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)

# Create two Vega.
v = features.Vega(data, position="absolute", left="50%", width="50%", height="50%")

v2 = features.Vega(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m)
f.add_child(m2)
f.add_child(v)
f.add_child(v2)

f

# %% [markdown]
# ### Vega-Lite div and a Map

# %%
import pandas as pd

N = 100

multi_iter2 = pd.DataFrame(
    {
        "x": np.random.uniform(size=(N,)),
        "y": np.random.uniform(size=(N,)),
    }
)

scatter = Chart(multi_iter2).mark_circle().encode(x="x", y="y")
scatter.width = 420
scatter.height = 250
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m = folium.Map(
    location=[0, 0],
    tiles="stamenwatercolor",
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m2 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)


# Create two Vega.
v = features.VegaLite(data, position="absolute", left="50%", width="50%", height="50%")

v2 = features.VegaLite(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m)
f.add_child(m2)
f.add_child(v)
f.add_child(v2)

f

# %% [markdown]
# ### GeoJson

# %%
N = 1000

lons = +5 - np.random.normal(size=N)
lats = 48 - np.random.normal(size=N)

data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "MultiPoint",
                "coordinates": [[lon, lat] for (lat, lon) in zip(lats, lons)],
            },
            "properties": {"prop0": "value0"},
        },
    ],
}

m = folium.Map([48, 5], zoom_start=6)
m.add_child(features.GeoJson(data))

m

# %% [markdown]
# ### Div

# %%
N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

d1 = f.add_subplot(1, 2, 1)
d2 = f.add_subplot(1, 2, 2)

d1.add_child(folium.Map([0, 0], tiles="stamenwatercolor", zoom_start=1))
d2.add_child(folium.Map([46, 3], tiles="OpenStreetMap", zoom_start=5))

f

# %% [markdown]
# ### LayerControl

# %%
m = folium.Map(tiles=None)

folium.raster_layers.TileLayer("OpenStreetMap").add_to(m)
folium.raster_layers.TileLayer("stamentoner").add_to(m)

folium.LayerControl().add_to(m)

m
